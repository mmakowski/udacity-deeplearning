# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

total_words = len(int_words)
word_counts = Counter(int_words)
threshold = 0.0001

def freq(word):
    return word_counts[word] / total_words

def discard_prob(word):
    return 1 - np.sqrt(threshold / freq(word))

def discard(word):
    return np.random.uniform() < discard_prob(word)

train_words = [] # The final subsampled word list
words_pbar = tqdm(int_words, desc='Subsampling', unit='words')
for word in words_pbar:
    if not discard(word):
        train_words.append(word)

print("Total words: {}".format(len(train_words)))
print("Unique words: {}".format(len(set(train_words))))
print([int_to_vocab[w] for w in train_words[:50]])
# Out:
# Subsampling: 100%|██████████| 16680599/16680599 [01:47<00:00, 154601.40words/s]
# Total words: 8388810
# Unique words: 63641
# ['anarchism', 'originated', 'term', 'abuse', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'revolution', 'sans', 'culottes', 'revolution', 'whilst', 'term', 'still', 'used', 'pejorative', 'way', 'describe', 'act', 'that', 'violent', 'means', 'destroy', 'organization', 'society', 'been', 'taken', 'positive', 'label', 'self', 'defined', 'anarchists', 'word', 'anarchism', 'derived', 'greek', 'archons', 'ruler', 'chief', 'anarchism', 'political', 'philosophy', 'belief', 'rulers', 'unnecessary', 'should']

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    return words[idx-window_size:idx] + words[idx+1:idx+window_size+1]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3f92bb1f373c> in <module>()
# ----> 1 train_graph = tf.Graph()
#       2 with train_graph.as_default():
#       3     inputs = tf.placeholder(tf.int32, [None])
#       4     labels = tf.placeholder(tf.int32, [None, 1])
#
# NameError: name 'tf' is not defined

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding)))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, num_sampled=100, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 18.6575 0.0871 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 18.4229 0.0831 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 18.0736 0.0832 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 17.9796 0.0832 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 17.7279 0.0834 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 17.4682 0.0836 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 17.3444 0.0834 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 17.1511 0.0833 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 17.0162 0.0827 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 16.8321 0.0826 sec/batch
# Nearest to may: traverse, perelman, autocorrelation, convictions, trinkets, stich, traumas, hyacinth,
# Nearest to was: template, amortized, fisher, keino, vectors, matejko, ft, bookshop,
# Nearest to years: seleucid, committees, stoa, morpheus, shoah, kut, bewilderment, apokryphen,
# Nearest to united: absalom, numerous, typhus, transients, equestrian, vena, argonauts, sticking,
# Nearest to the: pervez, lagos, haller, resided, probus, fema, kroni, trace,
# Nearest to all: protrudes, blackadder, exposures, haunted, trimurti, helaman, friction, uneven,
# Nearest to d: pilots, shel, starship, easily, zinoviev, fixer, separator, hostetler,
# Nearest to be: foam, shiga, infectious, dialect, gyms, lonely, rufinus, postumus,
# Nearest to marriage: horovitz, hornung, catarina, catamaran, grands, intercalary, triumphant, baden,
# Nearest to award: covey, pickled, protocols, lonesome, honoring, brazilians, nhadau, survives,
# Nearest to articles: users, landmark, hauser, oss, phu, danger, symposium, sabah,
# Nearest to units: randall, mentors, coaster, stratovolcano, helmet, pushcha, garnered, henchman,
# Nearest to running: philanthropic, balloons, pharaoh, rarity, coast, courts, process, cerro,
# Nearest to http: subtract, mikhalkov, interrogation, beechcraft, oliveira, campeador, esm, omar,
# Nearest to older: specifically, bruun, fluctuations, converge, contours, pursuers, thais, reclassification,
# Nearest to creation: counterexamples, montezuma, novelty, occupying, upgraded, osgood, misfortunes, volker,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 16.7515 0.0839 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 16.5508 0.0823 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 16.4100 0.0820 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 16.2170 0.0821 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 16.1067 0.0816 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 15.8279 0.0817 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 15.7533 0.0815 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 15.6483 0.0812 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 15.4273 0.0813 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 15.3283 0.0814 sec/batch
# Nearest to may: traverse, perelman, convictions, autocorrelation, stimulation, traumas, hyacinth, symmetrically,
# Nearest to was: template, fisher, vectors, keino, amortized, matejko, ft, bookshop,
# Nearest to years: seleucid, committees, kut, bewilderment, shoah, runciman, stoa, morpheus,
# Nearest to united: absalom, numerous, transients, typhus, equestrian, argonauts, robison, vena,
# Nearest to the: pervez, resided, probus, lagos, haller, fema, pahuin, leno,
# Nearest to all: protrudes, blackadder, exposures, trimurti, haunted, buddha, caan, helaman,
# Nearest to d: pilots, shel, easily, starship, ctss, separator, redacted, they,
# Nearest to be: foam, shiga, infectious, dialect, heteronormativity, escalate, gyms, symbolics,
# Nearest to marriage: horovitz, hornung, catamaran, catarina, intercalary, grands, established, triumphant,
# Nearest to award: covey, lonesome, protocols, pickled, brazilians, survives, honoring, nhadau,
# Nearest to articles: users, landmark, hauser, phu, oss, danger, sabah, ddg,
# Nearest to units: randall, mentors, coaster, pushcha, stratovolcano, helmet, garnered, liabilities,
# Nearest to running: philanthropic, balloons, rarity, coast, pharaoh, cerro, courts, sen,
# Nearest to http: subtract, beechcraft, oliveira, mikhalkov, interrogation, esm, campeador, omar,
# Nearest to older: specifically, bruun, fluctuations, converge, contours, pursuers, thais, blueberry,
# Nearest to creation: counterexamples, upgraded, montezuma, occupying, novelty, reruns, osgood, volker,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 15.1155 0.0825 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 15.0471 0.0817 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 14.9116 0.0811 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 14.7757 0.0816 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 14.6527 0.0817 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 14.4670 0.0816 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 14.2980 0.0815 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 14.1800 0.0813 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 14.0006 0.0812 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 13.9043 0.0812 sec/batch
# Nearest to may: traverse, convictions, hyacinth, stich, symmetrically, perelman, deakin, autocorrelation,
# Nearest to was: template, vectors, keino, fisher, bookshop, matejko, amortized, goalscorer,
# Nearest to years: seleucid, spartans, runciman, kut, committees, bewilderment, shoah, drip,
# Nearest to united: numerous, absalom, equestrian, transients, streptococcus, robison, typhus, argonauts,
# Nearest to the: than, about, ayala, fema, a, leno, bengali, trimming,
# Nearest to all: protrudes, buddha, exposures, loci, conduction, blackadder, trimurti, helaman,
# Nearest to d: pilots, starship, shel, easily, they, separator, redacted, hostetler,
# Nearest to be: foam, shiga, dialect, infectious, escalate, symbolics, heteronormativity, tachikoma,
# Nearest to marriage: hornung, horovitz, catamaran, catarina, intercalary, grands, established, dissipates,
# Nearest to award: covey, lonesome, protocols, pickled, honoring, nhadau, survives, lies,
# Nearest to articles: users, landmark, hauser, phu, oss, danger, symposium, sabah,
# Nearest to units: randall, mentors, pushcha, coaster, helmet, stratovolcano, garnered, faso,
# Nearest to running: philanthropic, balloons, rarity, coast, courts, pharaoh, sen, cerro,
# Nearest to http: oliveira, subtract, interrogation, beechcraft, mikhalkov, esm, afterburner, omar,
# Nearest to older: specifically, bruun, contours, pursuers, converge, fluctuations, thais, impolite,
# Nearest to creation: counterexamples, montezuma, occupying, upgraded, novelty, osgood, reruns, orinoco,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 13.8024 0.0822 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 13.7840 0.0810 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 13.5808 0.0813 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 13.4680 0.0815 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 13.3311 0.0813 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 13.2005 0.0805 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 13.0337 0.0807 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 12.8321 0.0814 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 12.7978 0.0806 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 12.7103 0.0809 sec/batch
# Nearest to may: to, hyacinth, stich, with, also, traverse, oceanographer, in,
# Nearest to was: the, template, provides, s, bookshop, enforced, is, dunraven,
# Nearest to years: seleucid, spartans, unforgiving, number, morpheus, soundly, kohoutek, drip,
# Nearest to united: numerous, absalom, equestrian, transients, streptococcus, typhus, thrower, robison,
# Nearest to the: a, in, and, to, as, of, for, is,
# Nearest to all: other, with, risks, founders, intensional, loci, conduction, be,
# Nearest to d: pilots, easily, they, starship, shel, redacted, hostetler, separator,
# Nearest to be: it, also, of, and, a, with, to, can,
# Nearest to marriage: horovitz, hornung, catarina, catamaran, intercalary, grands, dissipates, baden,
# Nearest to award: covey, eight, lonesome, protocols, lies, pickled, honoring, nhadau,
# Nearest to articles: users, landmark, phu, hauser, oss, levying, ddg, breaths,
# Nearest to units: randall, mentors, pushcha, helmet, coaster, garnered, stratovolcano, people,
# Nearest to running: philanthropic, balloons, rarity, pharaoh, coast, sen, brock, distancing,
# Nearest to http: oliveira, interrogation, beechcraft, esm, subtract, mikhalkov, afterburner, campeador,
# Nearest to older: specifically, contours, bruun, pursuers, converge, thais, motif, shaikh,
# Nearest to creation: montezuma, counterexamples, upgraded, occupying, novelty, osgood, reruns, orinoco,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 12.5409 0.0819 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 12.5451 0.0811 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 12.3679 0.0811 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 12.2374 0.0811 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 12.2743 0.0817 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 11.9839 0.0814 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 11.9419 0.0813 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 11.7339 0.0821 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 11.6738 0.0806 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 11.5256 0.0809 sec/batch
# Nearest to may: with, to, have, of, it, in, is, as,
# Nearest to was: the, s, is, a, to, and, in, as,
# Nearest to years: the, a, in, of, to, is, also, and,
# Nearest to united: equestrian, numerous, concerned, arise, neptune, streptococcus, absalom, on,
# Nearest to the: and, in, of, to, a, is, as, with,
# Nearest to all: with, be, to, is, the, a, and, as,
# Nearest to d: pilots, they, easily, starship, canter, separator, shel, hostetler,
# Nearest to be: a, to, of, and, the, is, in, with,
# Nearest to marriage: horovitz, hornung, catarina, catamaran, dissipates, grands, intercalary, baden,
# Nearest to award: all, eight, covey, lonesome, protocols, lies, survives, nhadau,
# Nearest to articles: users, landmark, phu, hauser, levying, ddg, reu, penises,
# Nearest to units: randall, pushcha, mentors, helmet, coaster, commonly, people, up,
# Nearest to running: philanthropic, balloons, rarity, pharaoh, coast, brock, accumulating, distancing,
# Nearest to http: oliveira, esm, interrogation, beechcraft, afterburner, subtract, campeador, mikhalkov,
# Nearest to older: specifically, contours, this, pursuers, converge, work, shaikh, bruun,
# Nearest to creation: montezuma, upgraded, occupying, counterexamples, reruns, osgood, novelty, prentice,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 11.5121 0.0818 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 11.2962 0.0806 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 11.1716 0.0809 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 11.1211 0.0809 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 11.0211 0.0803 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 11.0176 0.0811 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 10.8867 0.0809 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 10.7157 0.0808 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 10.5401 0.0805 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 10.4670 0.0806 sec/batch
# Nearest to may: to, with, a, it, as, and, have, is,
# Nearest to was: in, a, the, to, on, from, and, of,
# Nearest to years: s, of, a, the, in, and, from, with,
# Nearest to united: on, as, and, also, many, of, the, by,
# Nearest to the: of, in, and, a, to, with, by, as,
# Nearest to all: a, is, with, as, the, and, in, to,
# Nearest to d: easily, pilots, they, starship, hostetler, eight, mcing, separator,
# Nearest to be: to, it, a, is, this, with, and, as,
# Nearest to marriage: hornung, horovitz, catamaran, catarina, established, dissipates, grands, intercalary,
# Nearest to award: eight, all, lonesome, covey, lies, had, need, survives,
# Nearest to articles: users, landmark, phu, provide, levying, sabah, hauser, oss,
# Nearest to units: randall, people, pushcha, helmet, mentors, up, later, coaster,
# Nearest to running: philanthropic, rarity, elsewhere, balloons, coast, pharaoh, brock, accumulating,
# Nearest to http: oliveira, esm, interrogation, beechcraft, afterburner, muzorewa, mpla, cdma,
# Nearest to older: at, the, seven, a, on, and, of, this,
# Nearest to creation: montezuma, occupying, difficult, osgood, counterexamples, upgraded, orinoco, reruns,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 10.3419 0.0818 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 10.3463 0.0808 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 10.2200 0.0812 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 10.5604 0.0819 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 10.1580 0.0811 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 10.0318 0.0806 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 9.8888 0.0808 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 9.8333 0.0810 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 9.9880 0.0808 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 9.7943 0.0811 sec/batch
# Nearest to may: is, to, that, a, on, the, have, it,
# Nearest to was: the, by, in, and, of, to, from, s,
# Nearest to years: the, in, of, at, a, as, by, from,
# Nearest to united: of, in, the, first, and, was, from, to,
# Nearest to the: in, of, to, a, and, for, by, as,
# Nearest to all: with, to, the, a, in, it, which, but,
# Nearest to d: eight, seven, one, four, five, six, two, nine,
# Nearest to be: have, it, that, to, or, is, not, a,
# Nearest to marriage: established, horovitz, hornung, catamaran, catarina, dissipates, became, speed,
# Nearest to award: eight, influence, first, became, lies, lonesome, six, around,
# Nearest to articles: users, landmark, phu, provide, only, sabah, levying, danger,
# Nearest to units: randall, people, commonly, him, coaster, helmet, pushcha, claudette,
# Nearest to running: year, philanthropic, coast, without, rarity, elsewhere, least, into,
# Nearest to http: esm, oliveira, interrogation, beechcraft, afterburner, mpla, mikhalkov, muzorewa,
# Nearest to older: eight, became, after, by, seven, on, this, many,
# Nearest to creation: difficult, montezuma, upgraded, occupying, novelty, orinoco, counterexamples, reversed,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 9.4162 0.0820 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 9.5013 0.0806 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 9.6642 0.0808 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 9.5304 0.0808 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 9.4275 0.0809 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 9.3448 0.0810 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 8.9438 0.0814 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 9.2439 0.0818 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 9.0887 0.0830 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 9.0163 0.0844 sec/batch
# Nearest to may: to, which, or, for, with, the, a, an,
# Nearest to was: the, in, and, after, at, to, by, s,
# Nearest to years: over, zero, two, under, five, three, at, s,
# Nearest to united: of, in, after, new, was, the, during, were,
# Nearest to the: of, and, in, to, a, by, for, with,
# Nearest to all: for, a, the, to, in, as, of, and,
# Nearest to d: eight, one, seven, four, nine, five, three, six,
# Nearest to be: that, or, this, not, these, it, have, which,
# Nearest to marriage: established, over, become, government, became, then, had, due,
# Nearest to award: lies, th, after, became, world, influence, again, eight,
# Nearest to articles: users, landmark, provide, phu, course, named, related, eventually,
# Nearest to units: him, then, where, people, period, seen, if, following,
# Nearest to running: year, up, time, his, after, however, last, their,
# Nearest to http: esm, interrogation, oliveira, beechcraft, afterburner, mikhalkov, adding, honor,
# Nearest to older: became, were, during, after, then, before, into, new,
# Nearest to creation: upgraded, needed, stand, recent, now, level, difficult, occupying,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 9.0079 0.0843 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 8.9193 0.0836 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 8.8499 0.0835 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 8.8316 0.0103 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 8.6746 0.0824 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 8.5421 0.0830 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 8.5987 0.0823 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 8.5493 0.0825 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 8.5565 0.0836 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 8.4212 0.0832 sec/batch
# Nearest to may: a, is, or, this, there, an, in, by,
# Nearest to was: of, later, in, the, had, he, and, after,
# Nearest to years: over, of, under, in, the, s, on, first,
# Nearest to united: states, in, the, of, under, new, from, world,
# Nearest to the: in, of, and, a, from, to, on, with,
# Nearest to all: a, the, as, to, in, but, an, however,
# Nearest to d: nine, eight, one, seven, five, three, four, six,
# Nearest to be: that, a, this, is, or, an, same, not,
# Nearest to marriage: established, government, out, became, had, further, him, before,
# Nearest to award: last, new, eight, began, again, lies, one, six,
# Nearest to articles: related, took, users, named, provide, said, eventually, course,
# Nearest to units: period, him, yet, commonly, successful, if, larger, randall,
# Nearest to running: him, year, end, up, after, first, should, long,
# Nearest to http: external, links, city, esm, references, nearly, oliveira, based,
# Nearest to older: few, known, then, for, most, last, almost, became,
# Nearest to creation: difficult, level, recent, needed, kind, extended, stand, work,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 8.2183 0.0838 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 8.3333 0.0827 sec/batch
# Epoch 2/10 Iteration: 9300 Avg. Training loss: 8.3000 0.0820 sec/batch
# Epoch 2/10 Iteration: 9400 Avg. Training loss: 8.1939 0.0831 sec/batch
# Epoch 2/10 Iteration: 9500 Avg. Training loss: 8.1148 0.0832 sec/batch
# Epoch 2/10 Iteration: 9600 Avg. Training loss: 7.9296 0.0829 sec/batch
# Epoch 2/10 Iteration: 9700 Avg. Training loss: 8.0130 0.0824 sec/batch
# Epoch 2/10 Iteration: 9800 Avg. Training loss: 8.0025 0.0832 sec/batch
# Epoch 2/10 Iteration: 9900 Avg. Training loss: 7.8854 0.0837 sec/batch
# Epoch 2/10 Iteration: 10000 Avg. Training loss: 7.9419 0.0835 sec/batch
# Nearest to may: be, to, this, some, that, or, other, a,
# Nearest to was: in, had, on, first, the, after, s, and,
# Nearest to years: in, over, of, first, during, under, last, year,
# Nearest to united: states, became, world, established, during, in, war, its,
# Nearest to the: of, and, in, a, from, to, on, as,
# Nearest to all: as, the, a, of, for, which, and, is,
# Nearest to d: eight, seven, nine, one, six, five, four, three,
# Nearest to be: not, this, or, that, may, as, these, it,
# Nearest to marriage: established, government, gave, until, noted, south, both, numerous,
# Nearest to award: began, nine, was, january, home, year, his, eight,
# Nearest to articles: history, addition, official, related, external, their, links, at,
# Nearest to units: referred, on, period, major, yet, ten, about, main,
# Nearest to running: end, away, once, started, had, very, should, next,
# Nearest to http: links, external, references, city, english, history, returned, official,
# Nearest to older: little, years, began, only, in, there, was, last,
# Nearest to creation: its, than, needed, remained, nearly, recent, level, development,
# Epoch 2/10 Iteration: 10100 Avg. Training loss: 7.9357 0.0847 sec/batch
# Epoch 2/10 Iteration: 10200 Avg. Training loss: 7.8462 0.0830 sec/batch
# Epoch 2/10 Iteration: 10300 Avg. Training loss: 7.5478 0.0827 sec/batch
# Epoch 2/10 Iteration: 10400 Avg. Training loss: 7.4928 0.0829 sec/batch
# Epoch 2/10 Iteration: 10500 Avg. Training loss: 7.5468 0.0829 sec/batch
# Epoch 2/10 Iteration: 10600 Avg. Training loss: 7.5092 0.0831 sec/batch
# Epoch 2/10 Iteration: 10700 Avg. Training loss: 7.5608 0.0829 sec/batch
# Epoch 2/10 Iteration: 10800 Avg. Training loss: 7.5088 0.0830 sec/batch
# Epoch 2/10 Iteration: 10900 Avg. Training loss: 7.6510 0.0826 sec/batch
# Epoch 2/10 Iteration: 11000 Avg. Training loss: 7.6430 0.0825 sec/batch
# Nearest to may: a, such, or, to, is, these, that, some,
# Nearest to was: had, later, were, became, after, in, until, and,
# Nearest to years: zero, over, two, at, one, during, first, six,
# Nearest to united: states, world, established, national, countries, became, former, in,
# Nearest to the: and, in, a, of, for, to, by, as,
# Nearest to all: a, the, to, for, as, in, is, an,
# Nearest to d: j, nine, eight, seven, three, one, five, two,
# Nearest to be: can, this, such, not, is, or, any, it,
# Nearest to marriage: noted, gave, resulted, established, until, currently, over, decided,
# Nearest to award: home, his, began, lies, best, notable, played, successful,
# Nearest to articles: site, related, published, article, it, official, times, history,
# Nearest to units: mostly, making, follows, ten, man, an, needed, parts,
# Nearest to running: wide, back, away, on, end, continued, started, next,
# Nearest to http: links, external, com, www, references, article, reading, introduction,
# Nearest to older: every, below, age, there, living, and, years, the,
# Nearest to creation: largely, rather, development, often, general, independent, further, influence,
# Epoch 2/10 Iteration: 11100 Avg. Training loss: 7.5206 0.0839 sec/batch
# Epoch 2/10 Iteration: 11200 Avg. Training loss: 7.4170 0.0840 sec/batch
# Epoch 2/10 Iteration: 11300 Avg. Training loss: 7.1302 0.0836 sec/batch
# Epoch 2/10 Iteration: 11400 Avg. Training loss: 7.4341 0.0824 sec/batch
# Epoch 2/10 Iteration: 11500 Avg. Training loss: 7.2576 0.0829 sec/batch
# Epoch 2/10 Iteration: 11600 Avg. Training loss: 7.3531 0.0833 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 7.3006 0.0831 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 7.3362 0.0824 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 7.2781 0.0836 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 7.0237 0.0828 sec/batch
# Nearest to may: be, this, which, to, another, or, a, are,
# Nearest to was: had, his, he, were, after, in, began, s,
# Nearest to years: year, last, during, two, was, over, were, at,
# Nearest to united: states, state, national, world, countries, former, government, new,
# Nearest to the: in, of, and, from, a, to, for, by,
# Nearest to all: a, to, is, which, this, of, only, the,
# Nearest to d: one, eight, seven, six, nine, american, five, four,
# Nearest to be: can, are, or, is, this, different, not, have,
# Nearest to marriage: decided, house, established, resulted, wide, post, passed, fourth,
# Nearest to award: home, world, received, his, began, best, started, founded,
# Nearest to articles: site, history, full, external, help, books, official, started,
# Nearest to units: unit, rest, ten, mostly, follows, given, same, making,
# Nearest to running: up, with, run, first, from, line, at, several,
# Nearest to http: com, links, www, external, references, published, website, official,
# Nearest to older: age, below, years, every, size, there, over, line,
# Nearest to creation: work, rather, instead, an, others, in, of, the,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 6.9329 0.0841 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 7.0038 0.0828 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 7.0492 0.0829 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 7.0652 0.0828 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 6.9582 0.0827 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 6.8618 0.0829 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 6.9520 0.0829 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 6.8783 0.0833 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 7.1601 0.0835 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 6.8755 0.0836 sec/batch
# Nearest to may: or, is, that, not, it, some, be, this,
# Nearest to was: his, in, later, who, the, became, of, had,
# Nearest to years: year, in, after, over, were, until, during, last,
# Nearest to united: states, national, former, nations, america, established, kingdom, countries,
# Nearest to the: of, in, by, and, to, on, from, a,
# Nearest to all: to, for, is, a, this, as, that, only,
# Nearest to d: american, nine, one, eight, seven, german, six, three,
# Nearest to be: or, is, that, it, not, this, example, are,
# Nearest to marriage: shortly, house, gave, led, passed, huge, children, wife,
# Nearest to award: played, best, home, announced, returned, won, famous, during,
# Nearest to articles: article, online, site, help, previous, history, about, official,
# Nearest to units: taken, unit, a, second, is, primary, single, ten,
# Nearest to running: a, up, started, at, run, on, an, also,
# Nearest to http: com, www, links, org, collection, references, online, external,
# Nearest to older: age, living, below, alone, every, there, size, over,
# Nearest to creation: modern, could, for, to, up, which, even, already,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 6.6502 0.0842 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 6.5865 0.0831 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 6.8009 0.0831 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 6.8433 0.0829 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 6.8557 0.0838 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 6.7220 0.0833 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 6.5338 0.0830 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 6.6507 0.0824 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 6.5592 0.0831 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 6.7098 0.0834 sec/batch
# Nearest to may: which, but, to, or, however, a, it, that,
# Nearest to was: the, had, in, by, were, s, became, after,
# Nearest to years: over, age, year, and, after, s, the, one,
# Nearest to united: states, national, nations, member, government, state, nation, former,
# Nearest to the: in, of, and, by, from, to, were, which,
# Nearest to all: that, a, to, is, only, which, be, this,
# Nearest to d: american, eight, one, j, nine, john, six, robert,
# Nearest to be: is, this, that, not, because, or, any, example,
# Nearest to marriage: wife, mother, children, his, him, shortly, later, gave,
# Nearest to award: best, won, show, winning, awarded, received, series, appeared,
# Nearest to articles: online, article, books, published, numerous, discussion, references, external,
# Nearest to units: unit, small, expected, follows, determined, point, via, needed,
# Nearest to running: run, on, first, also, up, its, for, s,
# Nearest to http: www, com, org, links, external, website, online, reference,
# Nearest to older: age, over, living, with, up, part, time, few,
# Nearest to creation: by, of, the, for, to, further, however, as,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 6.6628 0.0835 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 6.6308 0.0832 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 6.3091 0.0837 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 6.4731 0.0832 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 6.3616 0.0829 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 6.3486 0.0837 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 6.4240 0.0827 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 6.6243 0.0832 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 6.4042 0.0831 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 6.4281 0.0832 sec/batch
# Nearest to may: is, only, all, for, which, however, this, also,
# Nearest to was: he, the, in, had, his, after, who, s,
# Nearest to years: under, over, after, of, age, the, last, in,
# Nearest to united: states, u, war, national, member, president, state, former,
# Nearest to the: of, to, by, from, in, and, with, as,
# Nearest to all: is, this, may, to, it, also, for, but,
# Nearest to d: b, american, author, one, eight, seven, nine, german,
# Nearest to be: not, it, that, or, should, any, have, because,
# Nearest to marriage: gave, wife, mother, his, daughter, whom, children, he,
# Nearest to award: best, won, winning, awarded, career, television, co, played,
# Nearest to articles: article, see, online, of, about, discussion, people, which,
# Nearest to units: unit, small, rest, point, slightly, expected, operations, large,
# Nearest to running: up, for, introduced, run, a, next, most, become,
# Nearest to http: www, com, org, guide, website, links, external, online,
# Nearest to older: age, a, and, where, up, living, long, from,
# Nearest to creation: among, and, as, which, other, a, to, the,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 6.3655 0.0845 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 6.4526 0.0833 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 6.6887 0.0834 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 6.3643 0.0836 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 6.0415 0.0828 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 6.3247 0.0833 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 6.4720 0.0831 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 6.3939 0.0833 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 6.2841 0.0832 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 6.1791 0.0827 sec/batch
# Nearest to may: or, that, be, any, these, this, which, such,
# Nearest to was: had, after, became, later, were, the, until, first,
# Nearest to years: age, over, under, population, months, year, july, five,
# Nearest to united: states, national, state, government, nations, established, former, civil,
# Nearest to the: and, in, of, to, with, by, from, on,
# Nearest to all: to, for, a, which, the, this, it, and,
# Nearest to d: b, american, writer, author, robert, born, italian, george,
# Nearest to be: this, any, that, can, or, not, will, these,
# Nearest to marriage: daughter, child, parents, his, son, whom, he, wife,
# Nearest to award: best, won, career, winning, director, awarded, robert, received,
# Nearest to articles: article, online, historical, history, discussion, of, and, from,
# Nearest to units: unit, amount, equal, large, result, base, is, smaller,
# Nearest to running: run, based, on, for, up, an, making, a,
# Nearest to http: www, com, org, links, website, external, online, guide,
# Nearest to older: age, families, below, living, up, there, an, every,
# Nearest to creation: as, view, with, however, being, to, ideas, which,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 5.9774 0.0843 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 6.3083 0.0828 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 6.1370 0.0831 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 6.1690 0.0831 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 6.2207 0.0836 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 6.1690 0.0831 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 6.2181 0.0833 sec/batch
# Epoch 3/10 Iteration: 16800 Avg. Training loss: 6.1986 0.0203 sec/batch
# Epoch 3/10 Iteration: 16900 Avg. Training loss: 6.1603 0.0831 sec/batch
# Epoch 3/10 Iteration: 17000 Avg. Training loss: 6.0270 0.0834 sec/batch
# Nearest to may: some, there, is, other, be, a, or, as,
# Nearest to was: had, were, later, became, first, on, after, s,
# Nearest to years: over, age, year, under, children, months, at, population,
# Nearest to united: states, national, state, established, britain, member, government, former,
# Nearest to the: and, of, in, as, by, from, to, a,
# Nearest to all: a, to, as, it, this, of, but, an,
# Nearest to d: b, writer, author, poet, american, prize, composer, born,
# Nearest to be: that, this, not, have, will, some, any, it,
# Nearest to marriage: father, married, wife, refused, she, her, child, whom,
# Nearest to award: best, academy, director, career, supporting, awarded, won, winning,
# Nearest to articles: article, foundation, new, of, public, see, by, history,
# Nearest to units: unit, base, is, called, operations, each, where, used,
# Nearest to running: run, up, a, for, performance, allowing, back, designed,
# Nearest to http: www, com, org, website, links, external, guide, uk,
# Nearest to older: together, as, known, for, only, some, there, most,
# Nearest to creation: this, to, that, but, their, it, as, although,
# Epoch 3/10 Iteration: 17100 Avg. Training loss: 6.0816 0.0840 sec/batch
# Epoch 3/10 Iteration: 17200 Avg. Training loss: 6.1508 0.0836 sec/batch
# Epoch 3/10 Iteration: 17300 Avg. Training loss: 6.0852 0.0834 sec/batch
# Epoch 3/10 Iteration: 17400 Avg. Training loss: 6.0259 0.0832 sec/batch
# Epoch 3/10 Iteration: 17500 Avg. Training loss: 5.9336 0.0830 sec/batch
# Epoch 3/10 Iteration: 17600 Avg. Training loss: 6.0588 0.0828 sec/batch
# Epoch 3/10 Iteration: 17700 Avg. Training loss: 6.1317 0.0829 sec/batch
# Epoch 3/10 Iteration: 17800 Avg. Training loss: 5.9781 0.0833 sec/batch
# Epoch 3/10 Iteration: 17900 Avg. Training loss: 5.8637 0.0832 sec/batch
# Epoch 3/10 Iteration: 18000 Avg. Training loss: 5.7843 0.0832 sec/batch
# Nearest to may: some, this, have, these, or, be, that, they,
# Nearest to was: first, later, had, after, were, s, became, during,
# Nearest to years: age, over, under, five, july, population, birth, year,
# Nearest to united: states, national, established, state, nations, u, kingdom, former,
# Nearest to the: in, and, of, from, by, with, also, on,
# Nearest to all: it, an, as, but, also, a, only, which,
# Nearest to d: writer, b, poet, composer, william, french, author, richard,
# Nearest to be: this, thus, or, these, not, such, because, that,
# Nearest to marriage: mother, father, son, his, death, children, wife, her,
# Nearest to award: best, academy, winning, film, career, won, artist, director,
# Nearest to articles: see, history, references, article, detailed, also, official, for,
# Nearest to units: unit, high, is, a, base, each, with, amount,
# Nearest to running: run, designed, introduced, available, a, allowing, only, making,
# Nearest to http: www, com, org, online, links, external, website, uk,
# Nearest to older: families, age, below, living, every, years, family, spread,
# Nearest to creation: to, an, that, but, some, all, as, it,
# Epoch 3/10 Iteration: 18100 Avg. Training loss: 5.9427 0.0840 sec/batch
# Epoch 3/10 Iteration: 18200 Avg. Training loss: 5.9173 0.0827 sec/batch
# Epoch 3/10 Iteration: 18300 Avg. Training loss: 5.8507 0.0831 sec/batch
# Epoch 3/10 Iteration: 18400 Avg. Training loss: 5.9085 0.0824 sec/batch
# Epoch 3/10 Iteration: 18500 Avg. Training loss: 5.9115 0.0826 sec/batch
# Epoch 3/10 Iteration: 18600 Avg. Training loss: 5.8428 0.0825 sec/batch
# Epoch 3/10 Iteration: 18700 Avg. Training loss: 5.6311 0.0830 sec/batch
# Epoch 3/10 Iteration: 18800 Avg. Training loss: 5.6557 0.0836 sec/batch
# Epoch 3/10 Iteration: 18900 Avg. Training loss: 5.6828 0.0832 sec/batch
# Epoch 3/10 Iteration: 19000 Avg. Training loss: 5.6953 0.0826 sec/batch
# Nearest to may: or, be, that, any, some, such, a, this,
# Nearest to was: later, had, after, were, came, until, during, took,
# Nearest to years: age, over, birth, population, zero, five, live, female,
# Nearest to united: states, world, nations, national, canada, countries, established, kingdom,
# Nearest to the: of, in, and, with, by, on, to, from,
# Nearest to all: a, as, for, or, this, only, but, not,
# Nearest to d: writer, poet, american, composer, b, jean, one, eight,
# Nearest to be: or, may, not, any, can, example, that, such,
# Nearest to marriage: her, father, she, wife, whom, married, son, daughter,
# Nearest to award: academy, best, awarded, awards, director, career, winning, american,
# Nearest to articles: external, online, see, detailed, page, article, list, history,
# Nearest to units: unit, combined, operations, high, operation, is, more, low,
# Nearest to running: run, designed, line, performance, next, available, single, top,
# Nearest to http: www, com, org, links, page, external, online, website,
# Nearest to older: below, families, every, together, as, alone, living, a,
# Nearest to creation: views, as, an, created, view, considered, that, regarding,
# Epoch 3/10 Iteration: 19100 Avg. Training loss: 5.7303 0.0831 sec/batch
# Epoch 3/10 Iteration: 19200 Avg. Training loss: 5.7159 0.0825 sec/batch
# Epoch 3/10 Iteration: 19300 Avg. Training loss: 5.8657 0.0826 sec/batch
# Epoch 3/10 Iteration: 19400 Avg. Training loss: 5.8708 0.0827 sec/batch
# Epoch 3/10 Iteration: 19500 Avg. Training loss: 5.8037 0.0836 sec/batch
# Epoch 3/10 Iteration: 19600 Avg. Training loss: 5.7105 0.0837 sec/batch
# Epoch 3/10 Iteration: 19700 Avg. Training loss: 5.5468 0.0829 sec/batch
# Epoch 3/10 Iteration: 19800 Avg. Training loss: 5.7950 0.0834 sec/batch
# Epoch 3/10 Iteration: 19900 Avg. Training loss: 5.6028 0.0831 sec/batch
# Epoch 3/10 Iteration: 20000 Avg. Training loss: 5.6902 0.0830 sec/batch
# Nearest to may: this, or, is, be, such, to, which, it,
# Nearest to was: had, later, after, he, were, began, became, eventually,
# Nearest to years: age, birth, live, population, over, year, female, during,
# Nearest to united: states, nation, canada, national, countries, established, world, kingdom,
# Nearest to the: of, and, by, in, to, from, a, as,
# Nearest to all: to, of, is, a, other, there, as, and,
# Nearest to d: one, nine, b, writer, poet, eight, six, composer,
# Nearest to be: any, can, this, it, is, or, so, possible,
# Nearest to marriage: wife, father, married, son, his, him, himself, who,
# Nearest to award: academy, best, awarded, won, series, winning, career, awards,
# Nearest to articles: comprehensive, historical, links, discussion, history, references, article, introduction,
# Nearest to units: unit, range, smaller, mass, more, a, compared, transfer,
# Nearest to running: run, line, wide, starting, on, top, designed, next,
# Nearest to http: www, com, org, links, external, website, page, online,
# Nearest to older: age, living, every, families, alone, below, in, there,
# Nearest to creation: scientific, principles, belief, view, idea, existence, ideas, that,
# Epoch 3/10 Iteration: 20100 Avg. Training loss: 5.7521 0.0842 sec/batch
# Epoch 3/10 Iteration: 20200 Avg. Training loss: 5.7618 0.0828 sec/batch
# Epoch 3/10 Iteration: 20300 Avg. Training loss: 5.7145 0.0825 sec/batch
# Epoch 3/10 Iteration: 20400 Avg. Training loss: 5.5241 0.0832 sec/batch
# Epoch 3/10 Iteration: 20500 Avg. Training loss: 5.4961 0.0831 sec/batch
# Epoch 3/10 Iteration: 20600 Avg. Training loss: 5.5355 0.0837 sec/batch
# Epoch 3/10 Iteration: 20700 Avg. Training loss: 5.6565 0.0838 sec/batch
# Epoch 3/10 Iteration: 20800 Avg. Training loss: 5.5686 0.0842 sec/batch
# Epoch 3/10 Iteration: 20900 Avg. Training loss: 5.5904 0.0841 sec/batch
# Epoch 3/10 Iteration: 21000 Avg. Training loss: 5.5109 0.0839 sec/batch
# Nearest to may: be, or, it, not, this, that, either, because,
# Nearest to was: later, after, had, became, were, his, during, soon,
# Nearest to years: age, during, five, in, at, over, under, birth,
# Nearest to united: states, nations, national, canada, kingdom, countries, established, france,
# Nearest to the: of, in, and, by, to, from, with, on,
# Nearest to all: a, this, is, as, which, same, it, or,
# Nearest to d: b, j, one, american, writer, eight, l, author,
# Nearest to be: is, this, or, it, because, are, must, different,
# Nearest to marriage: wife, married, father, her, he, his, who, himself,
# Nearest to award: academy, best, won, awards, golden, awarded, winning, career,
# Nearest to articles: external, comprehensive, links, online, article, see, history, references,
# Nearest to units: unit, amount, maximum, resulting, small, slightly, range, high,
# Nearest to running: run, up, runs, ran, start, designed, starting, top,
# Nearest to http: www, com, org, external, links, site, online, website,
# Nearest to older: age, families, alone, below, spread, living, there, every,
# Nearest to creation: scientific, work, principles, idea, which, yet, view, regarding,
# Epoch 3/10 Iteration: 21100 Avg. Training loss: 5.5421 0.0843 sec/batch
# Epoch 3/10 Iteration: 21200 Avg. Training loss: 5.5277 0.0840 sec/batch
# Epoch 3/10 Iteration: 21300 Avg. Training loss: 5.6874 0.0834 sec/batch
# Epoch 3/10 Iteration: 21400 Avg. Training loss: 5.5242 0.0832 sec/batch
# Epoch 3/10 Iteration: 21500 Avg. Training loss: 5.4157 0.0836 sec/batch
# Epoch 3/10 Iteration: 21600 Avg. Training loss: 5.3466 0.0838 sec/batch
# Epoch 3/10 Iteration: 21700 Avg. Training loss: 5.5266 0.0829 sec/batch
# Epoch 3/10 Iteration: 21800 Avg. Training loss: 5.5910 0.0831 sec/batch
# Epoch 3/10 Iteration: 21900 Avg. Training loss: 5.5882 0.0841 sec/batch
# Epoch 3/10 Iteration: 22000 Avg. Training loss: 5.4705 0.0839 sec/batch
# Nearest to may: this, that, which, be, all, it, or, to,
# Nearest to was: later, had, after, until, took, became, were, who,
# Nearest to years: over, age, months, population, three, twenty, five, year,
# Nearest to united: states, national, canada, member, nations, nation, federal, government,
# Nearest to the: in, of, and, by, from, to, with, were,
# Nearest to all: that, which, only, a, as, to, it, is,
# Nearest to d: b, writer, jean, american, physicist, poet, politician, composer,
# Nearest to be: this, not, that, therefore, thus, instead, might, will,
# Nearest to marriage: wife, whom, her, parents, mother, children, his, father,
# Nearest to award: best, awards, awarded, academy, winning, director, picture, won,
# Nearest to articles: online, encyclopedia, org, comprehensive, detailed, external, page, discussion,
# Nearest to units: unit, smaller, approximately, density, large, maximum, operations, mass,
# Nearest to running: run, up, designed, sold, top, runs, record, off,
# Nearest to http: www, com, org, external, website, links, online, html,
# Nearest to older: age, families, with, there, living, few, the, alone,
# Nearest to creation: nature, view, concerning, idea, that, as, being, beyond,
# Epoch 3/10 Iteration: 22100 Avg. Training loss: 5.3889 0.0841 sec/batch
# Epoch 3/10 Iteration: 22200 Avg. Training loss: 5.4939 0.0838 sec/batch
# Epoch 3/10 Iteration: 22300 Avg. Training loss: 5.4420 0.0836 sec/batch
# Epoch 3/10 Iteration: 22400 Avg. Training loss: 5.5017 0.0835 sec/batch
# Epoch 3/10 Iteration: 22500 Avg. Training loss: 5.5306 0.0836 sec/batch
# Epoch 3/10 Iteration: 22600 Avg. Training loss: 5.5273 0.0832 sec/batch
# Epoch 3/10 Iteration: 22700 Avg. Training loss: 5.2022 0.0831 sec/batch
# Epoch 3/10 Iteration: 22800 Avg. Training loss: 5.3600 0.0834 sec/batch
# Epoch 3/10 Iteration: 22900 Avg. Training loss: 5.3346 0.0830 sec/batch
# Epoch 3/10 Iteration: 23000 Avg. Training loss: 5.3104 0.0835 sec/batch
# Nearest to may: or, be, have, this, to, either, not, must,
# Nearest to was: had, were, later, until, became, came, after, took,
# Nearest to years: population, year, over, live, age, birth, s, nearly,
# Nearest to united: states, nations, member, government, established, nation, national, state,
# Nearest to the: of, in, and, by, with, to, as, from,
# Nearest to all: an, a, only, that, as, this, to, any,
# Nearest to d: b, j, w, l, one, r, two, c,
# Nearest to be: this, or, that, not, any, need, is, it,
# Nearest to marriage: her, married, death, mother, she, whom, his, children,
# Nearest to award: awards, best, academy, episode, director, awarded, artist, tony,
# Nearest to articles: article, encyclopedia, online, review, comprehensive, see, reading, journal,
# Nearest to units: unit, control, greater, the, and, small, measures, a,
# Nearest to running: run, introduced, access, up, designed, via, network, first,
# Nearest to http: www, org, com, links, external, html, archive, web,
# Nearest to older: introduced, than, few, up, below, a, like, especially,
# Nearest to creation: concerning, who, movement, own, been, was, issue, among,
# Epoch 3/10 Iteration: 23100 Avg. Training loss: 5.3626 0.0839 sec/batch
# Epoch 3/10 Iteration: 23200 Avg. Training loss: 5.4487 0.0831 sec/batch
# Epoch 3/10 Iteration: 23300 Avg. Training loss: 5.3386 0.0832 sec/batch
# Epoch 3/10 Iteration: 23400 Avg. Training loss: 5.3600 0.0844 sec/batch
# Epoch 3/10 Iteration: 23500 Avg. Training loss: 5.3729 0.0838 sec/batch
# Epoch 3/10 Iteration: 23600 Avg. Training loss: 5.5407 0.0851 sec/batch
# Epoch 3/10 Iteration: 23700 Avg. Training loss: 5.6634 0.0851 sec/batch
# Epoch 3/10 Iteration: 23800 Avg. Training loss: 5.3553 0.0838 sec/batch
# Epoch 3/10 Iteration: 23900 Avg. Training loss: 5.1388 0.0838 sec/batch
# Epoch 3/10 Iteration: 24000 Avg. Training loss: 5.3898 0.0834 sec/batch
# Nearest to may: to, for, only, this, however, a, which, with,
# Nearest to was: after, became, had, during, until, began, came, later,
# Nearest to years: birth, age, over, population, female, zero, five, year,
# Nearest to united: states, member, nations, national, state, federal, established, congress,
# Nearest to the: and, in, of, by, to, from, on, with,
# Nearest to all: to, a, which, this, for, with, have, that,
# Nearest to d: b, writer, poet, physicist, composer, politician, painter, mathematician,
# Nearest to be: or, any, therefore, that, because, this, is, will,
# Nearest to marriage: whom, parents, children, married, father, husband, daughter, he,
# Nearest to award: awards, best, academy, director, winning, hollywood, won, awarded,
# Nearest to articles: comprehensive, encyclopedia, article, discussion, review, online, journal, links,
# Nearest to units: unit, operations, mass, base, small, force, result, control,
# Nearest to running: run, up, top, single, record, company, sold, successful,
# Nearest to http: www, com, org, html, links, external, online, archive,
# Nearest to older: age, families, old, family, from, few, up, as,
# Nearest to creation: regarding, among, of, and, as, rejected, accepted, basis,
# Epoch 3/10 Iteration: 24100 Avg. Training loss: 5.4916 0.0846 sec/batch
# Epoch 3/10 Iteration: 24200 Avg. Training loss: 5.4272 0.0836 sec/batch
# Epoch 3/10 Iteration: 24300 Avg. Training loss: 5.3303 0.0832 sec/batch
# Epoch 3/10 Iteration: 24400 Avg. Training loss: 5.2497 0.0839 sec/batch
# Epoch 3/10 Iteration: 24500 Avg. Training loss: 5.1295 0.0835 sec/batch
# Epoch 3/10 Iteration: 24600 Avg. Training loss: 5.3596 0.0835 sec/batch
# Epoch 3/10 Iteration: 24700 Avg. Training loss: 5.2055 0.0833 sec/batch
# Epoch 3/10 Iteration: 24800 Avg. Training loss: 5.2746 0.0834 sec/batch
# Epoch 3/10 Iteration: 24900 Avg. Training loss: 5.2727 0.0831 sec/batch
# Epoch 3/10 Iteration: 25000 Avg. Training loss: 5.3014 0.0829 sec/batch
# Nearest to may: or, all, there, to, same, a, is, this,
# Nearest to was: had, before, after, later, until, made, in, began,
# Nearest to years: birth, age, female, male, under, population, children, year,
# Nearest to united: states, national, established, state, britain, federal, canada, government,
# Nearest to the: in, and, from, with, by, to, of, a,
# Nearest to all: the, to, a, that, this, an, for, with,
# Nearest to d: b, writer, poet, composer, politician, physicist, american, prize,
# Nearest to be: or, that, must, not, such, does, so, any,
# Nearest to marriage: couple, child, wife, whom, married, her, him, religious,
# Nearest to award: awards, best, academy, career, nominated, hollywood, appearances, film,
# Nearest to articles: comprehensive, online, page, detailed, guide, org, journal, information,
# Nearest to units: unit, mass, measures, small, combined, smaller, operations, base,
# Nearest to running: run, system, designed, available, for, ran, installed, commercial,
# Nearest to http: www, com, org, html, links, website, external, online,
# Nearest to older: together, for, families, an, only, are, while, ones,
# Nearest to creation: of, that, however, by, issue, beyond, has, attempts,
# Epoch 3/10 Iteration: 25100 Avg. Training loss: 5.3451 0.0838 sec/batch
# Epoch 4/10 Iteration: 25200 Avg. Training loss: 5.3619 0.0303 sec/batch
# Epoch 4/10 Iteration: 25300 Avg. Training loss: 5.1962 0.0833 sec/batch
# ...
# Epoch 9/10 Iteration: 75100 Avg. Training loss: 4.3161 0.0815 sec/batch
# Epoch 9/10 Iteration: 75200 Avg. Training loss: 4.2619 0.0805 sec/batch
# Epoch 9/10 Iteration: 75300 Avg. Training loss: 4.2491 0.0803 sec/batch
# Epoch 9/10 Iteration: 75400 Avg. Training loss: 4.3317 0.0807 sec/batch
# Epoch 10/10 Iteration: 75500 Avg. Training loss: 4.3652 0.0068 sec/batch
# Epoch 10/10 Iteration: 75600 Avg. Training loss: 4.2624 0.0807 sec/batch
# Epoch 10/10 Iteration: 75700 Avg. Training loss: 4.2831 0.0813 sec/batch
# Epoch 10/10 Iteration: 75800 Avg. Training loss: 4.2569 0.0814 sec/batch
# Epoch 10/10 Iteration: 75900 Avg. Training loss: 4.3095 0.0810 sec/batch
# Epoch 10/10 Iteration: 76000 Avg. Training loss: 4.2732 0.0805 sec/batch
# Nearest to may: or, occur, there, is, specific, are, be, associated,
# Nearest to was: had, after, later, became, his, came, he, the,
# Nearest to years: year, birth, remaining, months, age, over, last, twenty,
# Nearest to united: states, america, nations, kingdom, state, canada, u, australia,
# Nearest to the: of, in, by, and, which, from, to, a,
# Nearest to all: only, be, this, in, is, the, to, a,
# Nearest to d: b, writer, eight, one, politician, poet, composer, nine,
# Nearest to be: that, this, so, therefore, not, any, to, even,
# Nearest to marriage: marriages, divorce, marry, married, couple, child, wife, children,
# Nearest to award: awards, best, academy, nominated, oscar, achievement, nomination, awarded,
# Nearest to articles: discussion, page, org, links, biography, papers, review, encyclopedia,
# Nearest to units: unit, si, measurement, density, weights, infantry, mass, artillery,
# Nearest to running: run, line, behind, offensive, up, ran, down, runs,
# Nearest to http: www, htm, org, com, edu, html, website, wiki,
# Nearest to older: families, age, family, younger, median, household, children, years,
# Nearest to creation: created, concept, idea, entirely, creator, based, significance, create,
# Epoch 10/10 Iteration: 76100 Avg. Training loss: 4.2878 0.0815 sec/batch
# Epoch 10/10 Iteration: 76200 Avg. Training loss: 4.2689 0.0803 sec/batch
# Epoch 10/10 Iteration: 76300 Avg. Training loss: 4.2791 0.0803 sec/batch
# Epoch 10/10 Iteration: 76400 Avg. Training loss: 4.3222 0.0808 sec/batch
# Epoch 10/10 Iteration: 76500 Avg. Training loss: 4.2850 0.0812 sec/batch
# Epoch 10/10 Iteration: 76600 Avg. Training loss: 4.2755 0.0806 sec/batch
# Epoch 10/10 Iteration: 76700 Avg. Training loss: 4.1459 0.0809 sec/batch
# Epoch 10/10 Iteration: 76800 Avg. Training loss: 4.2667 0.0806 sec/batch
# Epoch 10/10 Iteration: 76900 Avg. Training loss: 4.2891 0.0801 sec/batch
# Epoch 10/10 Iteration: 77000 Avg. Training loss: 4.2803 0.0804 sec/batch
# Nearest to may: or, be, is, certain, can, there, are, normally,
# Nearest to was: had, after, first, took, later, became, eventually, soon,
# Nearest to years: over, age, year, zero, twenty, female, months, three,
# Nearest to united: states, kingdom, british, america, nations, countries, zealand, australia,
# Nearest to the: in, a, of, to, which, and, by, with,
# Nearest to all: the, to, is, only, a, this, of, but,
# Nearest to d: b, writer, politician, laureate, physicist, poet, eight, composer,
# Nearest to be: it, this, to, can, or, is, some, have,
# Nearest to marriage: divorce, marriages, married, marry, child, children, divorced, parents,
# Nearest to award: awards, best, academy, nominated, awarded, achievement, won, nomination,
# Nearest to articles: discussion, page, links, online, article, pages, information, org,
# Nearest to units: unit, army, infantry, brigade, forces, armed, artillery, si,
# Nearest to running: run, behind, end, up, line, down, back, just,
# Nearest to http: www, org, com, htm, html, links, external, edu,
# Nearest to older: age, families, household, years, family, females, median, versus,
# Nearest to creation: created, founding, of, create, concept, creator, framework, source,
# Epoch 10/10 Iteration: 77100 Avg. Training loss: 4.3031 0.0819 sec/batch
# Epoch 10/10 Iteration: 77200 Avg. Training loss: 4.2673 0.0806 sec/batch
# Epoch 10/10 Iteration: 77300 Avg. Training loss: 4.3214 0.0805 sec/batch
# Epoch 10/10 Iteration: 77400 Avg. Training loss: 4.2607 0.0809 sec/batch
# Epoch 10/10 Iteration: 77500 Avg. Training loss: 4.1739 0.0806 sec/batch
# Epoch 10/10 Iteration: 77600 Avg. Training loss: 4.1389 0.0807 sec/batch
# Epoch 10/10 Iteration: 77700 Avg. Training loss: 4.2348 0.0801 sec/batch
# Epoch 10/10 Iteration: 77800 Avg. Training loss: 4.2287 0.0802 sec/batch
# Epoch 10/10 Iteration: 77900 Avg. Training loss: 4.2225 0.0806 sec/batch
# Epoch 10/10 Iteration: 78000 Avg. Training loss: 4.1996 0.0798 sec/batch
# Nearest to may: or, be, can, these, generally, not, either, such,
# Nearest to was: had, later, after, were, became, until, took, first,
# Nearest to years: age, over, population, year, male, zero, birth, older,
# Nearest to united: states, kingdom, america, nations, british, countries, australia, zealand,
# Nearest to the: and, in, of, by, a, which, from, with,
# Nearest to all: only, any, which, that, same, this, not, to,
# Nearest to d: j, b, c, r, e, one, f, l,
# Nearest to be: can, therefore, cannot, that, this, not, any, is,
# Nearest to marriage: marriages, divorce, married, marry, wives, wife, child, her,
# Nearest to award: awards, awarded, best, academy, prize, winners, honors, nominated,
# Nearest to articles: links, page, online, article, encyclopedia, pages, history, publications,
# Nearest to units: unit, si, forces, charge, hundred, army, combined, conversion,
# Nearest to running: run, line, ran, along, runs, behind, across, home,
# Nearest to http: www, htm, com, org, html, links, edu, website,
# Nearest to older: age, families, alone, females, living, household, years, population,
# Nearest to creation: evolution, understanding, created, existence, scientific, view, issue, idea,
# Epoch 10/10 Iteration: 78100 Avg. Training loss: 4.2996 0.0807 sec/batch
# Epoch 10/10 Iteration: 78200 Avg. Training loss: 4.2716 0.0803 sec/batch
# Epoch 10/10 Iteration: 78300 Avg. Training loss: 4.2576 0.0809 sec/batch
# Epoch 10/10 Iteration: 78400 Avg. Training loss: 4.2369 0.0809 sec/batch
# Epoch 10/10 Iteration: 78500 Avg. Training loss: 4.3216 0.0803 sec/batch
# Epoch 10/10 Iteration: 78600 Avg. Training loss: 4.2012 0.0813 sec/batch
# Epoch 10/10 Iteration: 78700 Avg. Training loss: 4.2699 0.0806 sec/batch
# Epoch 10/10 Iteration: 78800 Avg. Training loss: 4.2500 0.0802 sec/batch
# Epoch 10/10 Iteration: 78900 Avg. Training loss: 4.3492 0.0810 sec/batch
# Epoch 10/10 Iteration: 79000 Avg. Training loss: 4.3060 0.0799 sec/batch
# Nearest to may: or, not, certain, be, cases, either, can, person,
# Nearest to was: later, had, became, were, after, first, began, took,
# Nearest to years: year, age, twenty, over, zero, last, three, period,
# Nearest to united: states, kingdom, countries, america, nations, established, canada, state,
# Nearest to the: in, of, a, from, and, by, as, with,
# Nearest to all: only, are, there, same, have, that, this, to,
# Nearest to d: b, one, eight, writer, poet, laureate, american, physicist,
# Nearest to be: can, because, it, this, not, only, a, same,
# Nearest to marriage: marriages, divorce, married, wife, wives, marry, relationship, couple,
# Nearest to award: awards, best, academy, received, awarded, achievement, nominated, winners,
# Nearest to articles: page, links, discussion, pages, external, detailed, online, comprehensive,
# Nearest to units: unit, si, per, density, quantity, charge, measurement, factor,
# Nearest to running: run, ran, wide, up, behind, line, end, off,
# Nearest to http: www, htm, org, com, html, edu, links, external,
# Nearest to older: age, families, alone, household, females, family, versus, population,
# Nearest to creation: evolution, scientific, created, belief, existence, genesis, universe, creator,
# Epoch 10/10 Iteration: 79100 Avg. Training loss: 4.2466 0.0812 sec/batch
# Epoch 10/10 Iteration: 79200 Avg. Training loss: 4.2063 0.0810 sec/batch
# Epoch 10/10 Iteration: 79300 Avg. Training loss: 4.1910 0.0804 sec/batch
# Epoch 10/10 Iteration: 79400 Avg. Training loss: 4.2811 0.0808 sec/batch
# Epoch 10/10 Iteration: 79500 Avg. Training loss: 4.2517 0.0805 sec/batch
# Epoch 10/10 Iteration: 79600 Avg. Training loss: 4.3138 0.0804 sec/batch
# Epoch 10/10 Iteration: 79700 Avg. Training loss: 4.2220 0.0801 sec/batch
# Epoch 10/10 Iteration: 79800 Avg. Training loss: 4.2365 0.0799 sec/batch
# Epoch 10/10 Iteration: 79900 Avg. Training loss: 4.2833 0.0803 sec/batch
# Epoch 10/10 Iteration: 80000 Avg. Training loss: 4.2125 0.0802 sec/batch
# Nearest to may: or, certain, are, be, usually, either, is, cases,
# Nearest to was: later, had, were, became, after, in, soon, until,
# Nearest to years: year, until, period, over, remaining, after, age, months,
# Nearest to united: states, nations, america, kingdom, first, canada, countries, usa,
# Nearest to the: in, of, to, by, a, which, from, with,
# Nearest to all: for, this, a, the, to, only, on, not,
# Nearest to d: b, one, eight, nine, seven, writer, politician, american,
# Nearest to be: not, it, can, that, to, is, this, any,
# Nearest to marriage: marriages, married, divorce, child, marry, couple, wives, wife,
# Nearest to award: awards, best, academy, achievement, awarded, honors, oscar, received,
# Nearest to articles: online, encyclopedia, page, org, article, links, com, web,
# Nearest to units: unit, si, force, measured, quantity, forces, equivalent, mass,
# Nearest to running: run, ran, behind, runs, off, down, up, passing,
# Nearest to http: www, htm, com, org, html, edu, links, site,
# Nearest to older: age, families, size, household, females, alone, below, family,
# Nearest to creation: created, creator, explanation, universe, evolution, genesis, intelligent, scientific,
# Epoch 10/10 Iteration: 80100 Avg. Training loss: 4.2889 0.0817 sec/batch
# Epoch 10/10 Iteration: 80200 Avg. Training loss: 4.2037 0.0812 sec/batch
# Epoch 10/10 Iteration: 80300 Avg. Training loss: 4.1455 0.0801 sec/batch
# Epoch 10/10 Iteration: 80400 Avg. Training loss: 4.3177 0.0804 sec/batch
# Epoch 10/10 Iteration: 80500 Avg. Training loss: 4.2589 0.0804 sec/batch
# Epoch 10/10 Iteration: 80600 Avg. Training loss: 4.3226 0.0804 sec/batch
# Epoch 10/10 Iteration: 80700 Avg. Training loss: 4.2677 0.0804 sec/batch
# Epoch 10/10 Iteration: 80800 Avg. Training loss: 4.2001 0.0803 sec/batch
# Epoch 10/10 Iteration: 80900 Avg. Training loss: 4.2755 0.0804 sec/batch
# Epoch 10/10 Iteration: 81000 Avg. Training loss: 4.2511 0.0800 sec/batch
# Nearest to may: either, or, be, not, a, however, certain, normally,
# Nearest to was: had, until, after, later, became, entered, in, remained,
# Nearest to years: over, year, period, last, zero, five, twenty, months,
# Nearest to united: states, nations, kingdom, countries, canada, america, u, national,
# Nearest to the: of, in, and, which, from, to, by, a,
# Nearest to all: be, is, that, any, only, a, to, not,
# Nearest to d: b, e, politician, l, j, r, physicist, laureate,
# Nearest to be: not, this, that, it, can, is, so, any,
# Nearest to marriage: married, divorce, marriages, wife, daughter, marry, child, her,
# Nearest to award: awards, best, hugo, awarded, academy, oscar, achievement, prize,
# Nearest to articles: online, page, encyclopedia, links, article, org, wikipedia, wiki,
# Nearest to units: unit, si, per, residing, force, mass, army, density,
# Nearest to running: run, ran, runs, operating, allowing, windows, passing, os,
# Nearest to http: www, htm, org, com, html, edu, links, external,
# Nearest to older: age, household, families, younger, below, size, family, females,
# Nearest to creation: created, development, proposed, idea, principles, based, genesis, universe,
# Epoch 10/10 Iteration: 81100 Avg. Training loss: 4.2972 0.0816 sec/batch
# Epoch 10/10 Iteration: 81200 Avg. Training loss: 4.2711 0.0797 sec/batch
# Epoch 10/10 Iteration: 81300 Avg. Training loss: 4.2636 0.0803 sec/batch
# Epoch 10/10 Iteration: 81400 Avg. Training loss: 4.1625 0.0801 sec/batch
# Epoch 10/10 Iteration: 81500 Avg. Training loss: 4.2113 0.0800 sec/batch
# Epoch 10/10 Iteration: 81600 Avg. Training loss: 4.2258 0.0797 sec/batch
# Epoch 10/10 Iteration: 81700 Avg. Training loss: 4.1916 0.0795 sec/batch
# Epoch 10/10 Iteration: 81800 Avg. Training loss: 4.3025 0.0803 sec/batch
# Epoch 10/10 Iteration: 81900 Avg. Training loss: 4.1192 0.0802 sec/batch
# Epoch 10/10 Iteration: 82000 Avg. Training loss: 4.2206 0.0800 sec/batch
# Nearest to may: is, or, of, be, this, for, the, either,
# Nearest to was: later, had, became, until, to, by, his, took,
# Nearest to years: year, remaining, birth, months, over, days, death, last,
# Nearest to united: states, u, president, state, kingdom, nations, virginia, war,
# Nearest to the: of, by, and, to, this, an, from, as,
# Nearest to all: is, only, this, there, not, the, be, same,
# Nearest to d: one, b, eight, seven, writer, nine, poet, composer,
# Nearest to be: not, that, any, it, because, even, to, but,
# Nearest to marriage: married, daughter, marry, marriages, couple, divorce, wife, child,
# Nearest to award: awards, best, hugo, academy, awarded, achievement, medal, winners,
# Nearest to articles: article, online, encyclopedia, page, discussion, website, org, com,
# Nearest to units: unit, si, customary, artillery, brigade, force, rank, infantry,
# Nearest to running: run, ran, next, wide, entire, runs, starts, up,
# Nearest to http: www, htm, com, org, html, edu, web, site,
# Nearest to older: age, younger, families, household, family, husband, children, adult,
# Nearest to creation: created, proposed, its, creating, creator, existence, principles, development,
# Epoch 10/10 Iteration: 82100 Avg. Training loss: 4.2994 0.0815 sec/batch
# Epoch 10/10 Iteration: 82200 Avg. Training loss: 4.3324 0.0801 sec/batch
# Epoch 10/10 Iteration: 82300 Avg. Training loss: 4.3022 0.0801 sec/batch
# Epoch 10/10 Iteration: 82400 Avg. Training loss: 4.4197 0.0802 sec/batch
# Epoch 10/10 Iteration: 82500 Avg. Training loss: 4.3246 0.0802 sec/batch
# Epoch 10/10 Iteration: 82600 Avg. Training loss: 4.1381 0.0802 sec/batch
# Epoch 10/10 Iteration: 82700 Avg. Training loss: 4.2812 0.0808 sec/batch
# Epoch 10/10 Iteration: 82800 Avg. Training loss: 4.2458 0.0807 sec/batch
# Epoch 10/10 Iteration: 82900 Avg. Training loss: 4.2374 0.0812 sec/batch
# Epoch 10/10 Iteration: 83000 Avg. Training loss: 4.2856 0.0809 sec/batch
# Nearest to may: or, either, any, can, be, normal, normally, is,
# Nearest to was: later, had, after, were, until, the, by, initially,
# Nearest to years: female, birth, age, life, male, year, months, mortality,
# Nearest to united: states, nations, state, virginia, washington, u, president, national,
# Nearest to the: by, which, and, in, of, a, to, from,
# Nearest to all: only, be, for, a, to, so, is, this,
# Nearest to d: b, e, j, physicist, laureate, politician, composer, writer,
# Nearest to be: can, not, that, this, any, because, to, but,
# Nearest to marriage: marry, marriages, divorce, married, daughter, wife, couple, child,
# Nearest to award: awards, best, academy, hugo, nominated, won, achievement, awarded,
# Nearest to articles: article, online, page, encyclopedia, discussion, org, links, detailed,
# Nearest to units: unit, si, mass, mi, density, rank, defined, approximately,
# Nearest to running: run, ran, operating, wide, core, making, up, runs,
# Nearest to http: www, htm, com, org, html, edu, external, web,
# Nearest to older: age, families, size, household, females, median, family, below,
# Nearest to creation: created, idea, creator, development, creating, concept, its, understanding,
# Epoch 10/10 Iteration: 83100 Avg. Training loss: 4.1979 0.0821 sec/batch
# Epoch 10/10 Iteration: 83200 Avg. Training loss: 4.0532 0.0810 sec/batch
# Epoch 10/10 Iteration: 83300 Avg. Training loss: 4.2986 0.0808 sec/batch
# Epoch 10/10 Iteration: 83400 Avg. Training loss: 4.2095 0.0811 sec/batch
# Epoch 10/10 Iteration: 83500 Avg. Training loss: 4.2482 0.0807 sec/batch
# Epoch 10/10 Iteration: 83600 Avg. Training loss: 4.2513 0.0805 sec/batch
# Epoch 10/10 Iteration: 83700 Avg. Training loss: 4.2343 0.0809 sec/batch
# Epoch 10/10 Iteration: 83800 Avg. Training loss: 4.2833 0.0811 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4eeca6a379f0> in <module>()
# ----> 1 with train_graph.as_default():
#       2     saver = tf.train.Saver()
#       3
#       4 with tf.Session(graph=train_graph) as sess:
#       5     saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
#
# NameError: name 'train_graph' is not defined

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
